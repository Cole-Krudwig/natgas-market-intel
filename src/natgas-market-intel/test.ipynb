# %%
import pandas as pd
import duckdb

# %%
con = duckdb.connect('data/commodities.duckdb')

# %%
df = con.execute("""
    SELECT *
    FROM futures_daily
    ORDER BY date asc
    LIMIT 100
""").df()

df
# Out:
#          date     symbol root  contract_year  contract_month   open   high  \
# 0  1999-12-31  NGX01.NYM   NG           2001              11  2.563  2.563
# 1  1999-12-31  NGZ01.NYM   NG           2001              12  2.688  2.688
# 2  1999-12-31  NGV01.NYM   NG           2001              10  2.435  2.435
# 3  1999-12-31  NGQ01.NYM   NG           2001               8  2.395  2.395
# 4  1999-12-31  NGM01.NYM   NG           2001               6  2.378  2.378
# ..        ...        ...  ...            ...             ...    ...    ...
# 95 2000-01-10  NGQ01.NYM   NG           2001               8  2.403  2.403
# 96 2000-01-10  NGU02.NYM   NG           2002               9  2.420  2.420
# 97 2000-01-10  NGF02.NYM   NG           2002               1  2.723  2.723
# 98 2000-01-10  NGJ02.NYM   NG           2002               4  2.417  2.417
# 99 2000-01-10  NGV02.NYM   NG           2002              10  2.453  2.453
#
# ...

# %%
con.close()
